# %%
# Reading in data and verify it is the same set as the book
path1 = 'C:/Users/casey/Dropbox/SMU_DataScience/MSDS_7333_QuantifyingTheWorld/Homework/CaseStudy1/offline.final.trace.txt'
path2 = "/home/kyle/Documents/thomaskh522@gmail.com/SMU/Quant the World/RTLS_CaseStudy/Data/offline_data.txt"

# data = readLines(path1)
# sum(substr(data, 1,1) == "#")
# length(data)

# %%
# The Data matches
# Process the data
strsplit(data[4], ";")[[1]]
# Out:
#  [1] "t=1139643118358"                    "id=00:02:2D:21:0F:33"
#  [3] "pos=0.0,0.0,0.0"                    "degree=0.0"
#  [5] "00:14:bf:b1:97:8a=-38,2437000000,3" "00:14:bf:b1:97:90=-56,2427000000,3"
#  [7] "00:0f:a3:39:e1:c0=-53,2462000000,3" "00:14:bf:b1:97:8d=-65,2442000000,3"
#  [9] "00:14:bf:b1:97:81=-65,2422000000,3" "00:14:bf:3b:c7:c6=-66,2432000000,3"
# [11] "00:0f:a3:39:dd:cd=-75,2412000000,3" "00:0f:a3:39:e0:4b=-78,2462000000,3"
# [13] "00:0f:a3:39:e2:10=-87,2437000000,3" "02:64:fb:68:52:e6=-88,2447000000,1"
# [15] "02:00:42:55:31:00=-84,2457000000,1"

# %%
unlist(lapply(strsplit(data[4], ";")[[1]], function(x) sapply(strsplit(x, "=")[[1]], strsplit, ",")))
# Out:
#                   t       1139643118358                  id   00:02:2D:21:0F:33
#                 "t"     "1139643118358"                "id" "00:02:2D:21:0F:33"
#                 pos        0.0,0.0,0.01        0.0,0.0,0.02        0.0,0.0,0.03
#               "pos"               "0.0"               "0.0"               "0.0"
#              degree                 0.0   00:14:bf:b1:97:8a   -38,2437000000,31
#            "degree"               "0.0" "00:14:bf:b1:97:8a"               "-38"
#   -38,2437000000,32   -38,2437000000,33   00:14:bf:b1:97:90   -56,2427000000,31
#        "2437000000"                 "3" "00:14:bf:b1:97:90"               "-56"
#   -56,2427000000,32   -56,2427000000,33   00:0f:a3:39:e1:c0   -53,2462000000,31
#        "2427000000"                 "3" "00:0f:a3:39:e1:c0"               "-53"
#   -53,2462000000,32   -53,2462000000,33   00:14:bf:b1:97:8d   -65,2442000000,31
#        "2462000000"                 "3" "00:14:bf:b1:97:8d"               "-65"
# ...

# %%
tokens = strsplit(data[4], "[;=,]")[[1]]

# %%
tokens
# Out:
#  [1] "t"                 "1139643118358"     "id"
#  [4] "00:02:2D:21:0F:33" "pos"               "0.0"
#  [7] "0.0"               "0.0"               "degree"
# [10] "0.0"               "00:14:bf:b1:97:8a" "-38"
# [13] "2437000000"        "3"                 "00:14:bf:b1:97:90"
# [16] "-56"               "2427000000"        "3"
# [19] "00:0f:a3:39:e1:c0" "-53"               "2462000000"
# [22] "3"                 "00:14:bf:b1:97:8d" "-65"
# [25] "2442000000"        "3"                 "00:14:bf:b1:97:81"
# [28] "-65"               "2422000000"        "3"
# [31] "00:14:bf:3b:c7:c6" "-66"               "2432000000"
# [34] "3"                 "00:0f:a3:39:dd:cd" "-75"
# [37] "2412000000"        "3"                 "00:0f:a3:39:e0:4b"
# [40] "-78"               "2462000000"        "3"
# [43] "00:0f:a3:39:e2:10" "-87"               "2437000000"
# [46] "3"                 "02:64:fb:68:52:e6" "-88"
# [49] "2447000000"        "1"                 "02:00:42:55:31:00"
# ...

# %%
tokens[1:10]
# Out:
#  [1] "t"                 "1139643118358"     "id"
#  [4] "00:02:2D:21:0F:33" "pos"               "0.0"
#  [7] "0.0"               "0.0"               "degree"
# [10] "0.0"

# %%
tokens[c(2,4, 6:8, 10)]
# Out:
# [1] "1139643118358"     "00:02:2D:21:0F:33" "0.0"
# [4] "0.0"               "0.0"               "0.0"

# %%
tmp = matrix(tokens[ - (1:10)], ncol=4, byrow = TRUE)
mat = cbind(matrix(tokens[c(2,4, 6:8, 10)], nrow = nrow(tmp), ncol = 6, byrow=TRUE), tmp)

# %%
dim(mat)
# Out:
# [1] 11 10

# %%
processLine = 
function(x)
    {
    tokens = strsplit(x, "[;=,]")[[1]]
    
    if (length(tokens) == 10)
        return(NULL)
    tmp = matrix(tokens[-(1:10)], ncol=4, byrow = TRUE)
    cbind(matrix(tokens[c(2,4,6:8,10)], nrow = nrow(tmp), ncol=6, byrow=TRUE), tmp)
}

tmp = lapply(data[4:20], processLine)

# %%
sapply(tmp, nrow)
# Out:
#  [1] 11 10 10 11  9 10  9  9 10 11 11  9  9  9  8 10 14

# %%
offline = as.data.frame(do.call("rbind", tmp))
dim(offline)
# Out:
# [1] 170  10

# %%
# Make the data set
options(error = recover, warn=1)
lines = data[substr(data,1,1) != "#"]
tmp = lapply(lines, processLine)
offline = as.data.frame(do.call("rbind", tmp), stringsAsFactors = FALSE)
dim(offline)
# Out:
# [1] 1181628      10

# %% [markdown]
# # PICK UP WITH  1.3 Cleaning the Data and Building a Representation for Analysis

# %%
names(offline) = c("time", "scanMac", "posX", "posY", "posZ", "orientation", "mac", "signal", "channel", "type")

# %%
numVars = c("time", "posX", "posY", "posZ", "orientation", "signal")
offline[numVars] = lapply(offline[numVars], as.numeric)

# %%
head(offline)
# Out:
#   time         scanMac           posX posY posZ orientation mac
# 1 1.139643e+12 00:02:2D:21:0F:33 0    0    0    0           00:14:bf:b1:97:8a
# 2 1.139643e+12 00:02:2D:21:0F:33 0    0    0    0           00:14:bf:b1:97:90
# 3 1.139643e+12 00:02:2D:21:0F:33 0    0    0    0           00:0f:a3:39:e1:c0
# 4 1.139643e+12 00:02:2D:21:0F:33 0    0    0    0           00:14:bf:b1:97:8d
# 5 1.139643e+12 00:02:2D:21:0F:33 0    0    0    0           00:14:bf:b1:97:81
# 6 1.139643e+12 00:02:2D:21:0F:33 0    0    0    0           00:14:bf:3b:c7:c6
#   signal channel    type
# 1 -38    2437000000 3
# 2 -56    2427000000 3
# 3 -53    2462000000 3
# 4 -65    2442000000 3
# 5 -65    2422000000 3
# 6 -66    2432000000 3

# %%
offline = offline[offline$type == "3",]
offline = offline[, "type" != names(offline)]
dim(offline)
# Out:
# [1] 978443      9

# %%
offline$rawtime = offline$time
offline$time = offline$time/1000
class(offline$time) = c("POSIXt", "POSIXct")
unlist(lapply(offline, class))
# Out:
#       time1       time2     scanMac        posX        posY        posZ
#    "POSIXt"   "POSIXct" "character"   "numeric"   "numeric"   "numeric"
# orientation         mac      signal     channel     rawtime
#   "numeric" "character"   "numeric" "character"   "numeric"

# %%
summary(offline[, numVars])
# Out:
#       time                          posX            posY             posZ
#  Min.   :2006-02-11 01:31:58   Min.   : 0.00   Min.   : 0.000   Min.   :0
#  1st Qu.:2006-02-11 07:21:27   1st Qu.: 2.00   1st Qu.: 3.000   1st Qu.:0
#  Median :2006-02-11 13:57:58   Median :12.00   Median : 6.000   Median :0
#  Mean   :2006-02-16 08:57:37   Mean   :13.52   Mean   : 5.897   Mean   :0
#  3rd Qu.:2006-02-19 08:52:40   3rd Qu.:23.00   3rd Qu.: 8.000   3rd Qu.:0
#  Max.   :2006-03-09 14:41:10   Max.   :33.00   Max.   :13.000   Max.   :0
#   orientation        signal
#  Min.   :  0.0   Min.   :-99.0
#  1st Qu.: 90.0   1st Qu.:-69.0
#  Median :180.0   Median :-60.0
#  Mean   :167.2   Mean   :-61.7
#  3rd Qu.:270.0   3rd Qu.:-53.0
#  Max.   :359.9   Max.   :-25.0

# %%
summary(sapply(offline[, c("mac", "channel", "scanMac")], as.factor))
# Out:
#                 mac               channel                    scanMac
#  00:0f:a3:39:e1:c0:145862   2462000000:189774   00:02:2D:21:0F:33:978443
#  00:0f:a3:39:dd:cd:145619   2437000000:152124
#  00:14:bf:b1:97:8a:132962   2412000000:145619
#  00:14:bf:3b:c7:c6:126529   2432000000:126529
#  00:14:bf:b1:97:90:122315   2427000000:122315
#  00:14:bf:b1:97:8d:121325   2442000000:121325
#  (Other)          :183831   (Other)   :120757

# %%
offline = offline[, !(names(offline) %in% c("scanMac", "posZ"))]

# %%
length(unique(offline$orientation))
# Out:
# [1] 203

# %%
plot(ecdf(offline$orientation))
# Out:
# Plot with title "ecdf(offline$orientation)"

# %%
roundOrientation = function(angles) {
    refs = seq(0, by = 45, length = 9)
    q = sapply(angles, function(o) which.min(abs(o-refs)))
    c(refs[1:8], 0)[q]
}
               
offline$angle = roundOrientation(offline$orientation)

# %%
with(offline, boxplot(orientation ~ angle, xlab = "nearest 45 degree angle", ylab="orientation"))
# Out:
# plot without title

# %% [markdown]
# ## 1.3.2 Exploring MAC Addresses

# %%
c(length(unique(offline$mac)), length(unique(offline$channel)))
# Out:
# [1] 12  8

# %%
table(offline$mac)
# Out:
# 00:04:0e:5c:23:fc 00:0f:a3:39:dd:cd 00:0f:a3:39:e0:4b 00:0f:a3:39:e1:c0
#               418            145619             43508            145862
# 00:0f:a3:39:e2:10 00:14:bf:3b:c7:c6 00:14:bf:b1:97:81 00:14:bf:b1:97:8a
#             19162            126529            120339            132962
# 00:14:bf:b1:97:8d 00:14:bf:b1:97:90 00:30:bd:f8:7f:c5 00:e0:63:82:8b:a9
#            121325            122315               301               103

# %%
submac = names(sort(table(offline$mac), decreasing = TRUE))[1:7]
offline = offline[offline$mac %in% submac,]

# %%
macChannel = with(offline, table(mac, channel))
apply(macChannel, 1, function(x) sum(x > 0))
# Out:
# 00:0f:a3:39:dd:cd 00:0f:a3:39:e1:c0 00:14:bf:3b:c7:c6 00:14:bf:b1:97:81
#                 1                 1                 1                 1
# 00:14:bf:b1:97:8a 00:14:bf:b1:97:8d 00:14:bf:b1:97:90
#                 1                 1                 1

# %%
offline = offline[, "channel" != names(offline)]

# %% [markdown]
# ## Exploring the Position of the Hand-Held Device

# %%
locDF = with(offline, by(offline, list(posX, posY), function(x) x))
length(locDF)
# Out:
# [1] 476

# %%
sum(sapply(locDF, is.null))
# Out:
# [1] 310

# %%
locDF = locDF[ !sapply(locDF, is.null)]

# %%
length(locDF)
# Out:
# [1] 166

# %%
locCounts = sapply(locDF, nrow)
locCounts = sapply(locDF, function(df) c(df[1, c("posX", "posY")], count= nrow(df)))

# %%
class(locCounts)
# Out:
# [1] "matrix"

# %%
dim(locCounts)
# Out:
# [1]   3 166

# %%
locCounts = t(locCounts)

# %%
plot(locCounts, type="n", xlab="", ylab="")
text(locCounts, labels = locCounts[,3], cex=0.8, srt = 45)
# Out:
# plot without title

# %% [markdown]
# ## 1.3.4 Creating a Function to Prepare Data
# Instead I am just going to write the data to CSV so that I can use it when needed.

# %%
# write.csv(offline, file = "cleaned_offline.csv")
readData = 
  function(filename = 'offline.final.trace.txt', 
           subMacs = c("00:0f:a3:39:e1:c0", "00:0f:a3:39:dd:cd", "00:14:bf:b1:97:8a",
                       "00:14:bf:3b:c7:c6", "00:14:bf:b1:97:90", "00:14:bf:b1:97:8d",
                       "00:14:bf:b1:97:81"))
  {
    txt = readLines(filename)
    lines = txt[ substr(txt, 1, 1) != "#" ]
    tmp = lapply(lines, processLine)
    offline = as.data.frame(do.call("rbind", tmp), 
                            stringsAsFactors= FALSE) 
    
    names(offline) = c("time", "scanMac", 
                       "posX", "posY", "posZ", "orientation", 
                       "mac", "signal", "channel", "type")
    
     # keep only signals from access points
    offline = offline[ offline$type == "3", ]
    
    # drop scanMac, posZ, channel, and type - no info in them
    dropVars = c("scanMac", "posZ", "channel", "type")
    offline = offline[ , !( names(offline) %in% dropVars ) ]
    
    # drop more unwanted access points
    offline = offline[ offline$mac %in% subMacs, ]
    
    # convert numeric values
    numVars = c("time", "posX", "posY", "orientation", "signal")
    offline[ numVars ] = lapply(offline[ numVars ], as.numeric)

    # convert time to POSIX
    offline$rawTime = offline$time
    offline$time = offline$time/1000
    class(offline$time) = c("POSIXt", "POSIXct")
    
    # round orientations to nearest 45
    offline$angle = roundOrientation(offline$orientation)
      
    return(offline)
  }

# %% [markdown]
# ## 1.4 Signal Strength Analysis

# %%
library(lattice)
bwplot(signal ~ factor(angle) | mac, data = offline, subset = posX == 2 & posY == 12 & mac != "00:0f:a3:39:dd:cd", layout = c(2,3))
# Out:
# plot without title

# %%
densityplot( ~ signal | mac + factor(angle), data = offline, subset = posX == 24 & posY == 4 & mac != "00:0f:a3:39:dd:cd", bw = 0.5, plot.points = FALSE)
# Out:
# plot without title

# %%
offline$posXY = paste(offline$posX, offline$posY, sep = "-")

# %%
byLocAngleAP = with(offline, by(offline, list(posXY, angle, mac), function(x) x))

# %%
signalSummary = lapply(byLocAngleAP,
                       function(oneLoc){
                            ans = oneLoc[1,]
                            ans$medSignal = median(oneLoc$signal)
                            ans$avgSignal = mean(oneLoc$signal)
                            ans$num = length(oneLoc$signal)
                            ans$sdSignal = sd(oneLoc$signal)
                            ans$iqrSignal = IQR(oneLoc$signal)
                            ans
                        })

offlineSummary = do.call("rbind", signalSummary)

# %%
breaks = seq(-90, -30, by = 5)
bwplot(sdSignal ~ cut(avgSignal, breaks = breaks), data = offlineSummary, subset =  mac != "00:0f:a3:39:dd:cd",
      xlab = "Mean Signal", ylab = "SD Signal")
# Out:
# plot without title

# %%
with(offlineSummary, smoothScatter( (avgSignal - medSignal) ~ num, xlab = "Number of Observations", ylab = "mean - median"))
abline(h = 0, col = "#984ea3", lwd = 2)
# Out:
# plot without title

# %%
lo.obj = with(offlineSummary, loess(diff ~ num, data = data.frame(diff = (avgSignal - medSignal), num = num)))

# %%
plot.new
lo.obj.pr = predict(lo.obj, newdata = data.frame(num = (70:120)))
lines(x=70:120, y=lo.obj.pr, col = "#4daf4a", lwd=2)
# Out:
# function ()
# {
#     for (fun in getHook("before.plot.new")) {
#         if (is.character(fun))
#             fun <- get(fun)
#         try(fun())
#     }
#     .External2(C_plot_new)
#     grDevices:::recordPalette()
#     for (fun in getHook("plot.new")) {
#         if (is.character(fun))
#             fun <- get(fun)
#         try(fun())
#     }
#     invisible()
# }
# <bytecode: 0x88c1d70>
# <environment: namespace:graphics>
# Error in plot.xy(xy.coords(x, y), type = type, ...): plot.new has not been called yet
# Traceback:
#
# 1. lines(x = 70:120, y = lo.obj.pr, col = "#4daf4a", lwd = 2)
# 2. lines.default(x = 70:120, y = lo.obj.pr, col = "#4daf4a", lwd = 2)
# 3. plot.xy(xy.coords(x, y), type = type, ...)

# %%
oneAPAngle = subset(offlineSummary, 
                    mac == submac[5] & angle == 0)

# %%
# install.packages('fields')
library(fields)
smoothSS = Tps(oneAPAngle[, c("posX", "posY")], oneAPAngle$avgSignal)
# Out:
# Loading required package: spam
# Loading required package: dotCall64
# Loading required package: grid
# Spam version 2.1-2 (2017-12-21) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
# Attaching package: ‘spam’
#
# The following objects are masked from ‘package:base’:
#
#     backsolve, forwardsolve
#
# Loading required package: maps

# %%
vizSmooth = predictSurface(smoothSS)

# %%
plot.surface(vizSmooth, type = "C")
points(oneAPAngle$posX, oneAPAngle$posY, pch=19, cex= 0.5)
# Out:
# plot without title

# %%
surfaceSS = function(data, mac, angle = 45) {
  require(fields)
  oneAPAngle = data[ data$mac == mac & data$angle == angle, ]
  smoothSS = Tps(oneAPAngle[, c("posX","posY")], 
                 oneAPAngle$avgSignal)
  vizSmooth = predictSurface(smoothSS)
  plot.surface(vizSmooth, type = "C", 
               xlab = "", ylab = "", xaxt = "n", yaxt = "n")
  points(oneAPAngle$posX, oneAPAngle$posY, pch=19, cex = 0.5) 
}

parCur = par(mfrow = c(2,2), mar = rep(1, 4))

mapply(surfaceSS, mac = submac[ rep(c(5, 1), each = 2) ], 
       angle = rep(c(0, 135), 2),
       data = list(data = offlineSummary))
 
par(parCur)

offlineSummary = subset(offlineSummary, mac != subMacs[2])
# Out:
# ERROR while rich displaying an object: Error in vapply(seq_along(mapped), function(i) {: values must be length 1,
#  but FUN(X[[1]]) result is length 0
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_html.list(obj)
# 9. repr_list_generic(obj, "html", "\t<li>%s</li>\n", "\t<dt>$%s</dt>\n\t\t<dd>%s</dd>\n",
#  .     "<strong>$%s</strong> = %s", "<ol>\n%s</ol>\n", "<dl>\n%s</dl>\n",
# ...

# %%
offlineSummary = subset(offlineSummary, mac != submac[2])

# %%
AP = matrix( c(7.5, 6.3, 2.5, -.8, 12.8, -2.8, 1, 14, 33.5, 9.3, 33.5, 2.8), ncol = 2, byrow = TRUE, 
           dimnames = list(submac[-2], c("x", "y") ))

AP
# Out:
#                   x    y
# 00:0f:a3:39:e1:c0  7.5  6.3
# 00:14:bf:b1:97:8a  2.5 -0.8
# 00:14:bf:3b:c7:c6 12.8 -2.8
# 00:14:bf:b1:97:90  1.0 14.0
# 00:14:bf:b1:97:8d 33.5  9.3
# 00:14:bf:b1:97:81 33.5  2.8

# %%
diffs = offlineSummary[ , c("posX", "posY")] - AP[offlineSummary$mac, ]
diffs
# Out:
#         posX posY
# 3       -7.5 -6.3
# 24507   -7.5 -5.3
# 221774  -7.5  3.7
# 229185  -7.5  4.7
# 236489  -7.5  5.7
# 243539  -7.5  6.7
# 49625   -7.5 -4.3
# 73864   -7.5 -3.3
# 99008   -7.5 -2.3
# 199295  -7.5  0.7
# 207187  -7.5  1.7
# 214634  -7.5  2.7
# 8313    -6.5 -6.3
# 32848   -6.5 -5.3
# 170127  -6.5  3.7
# 177657  -6.5  4.7
# 184971  -6.5  5.7
# 192298  -6.5  6.7
# 57598   -6.5 -4.3
# 82305   -6.5 -3.3
# 107322  -6.5 -2.3
# 123372  -6.5 -1.3
# 138863  -6.5 -0.3
# 146964  -6.5  0.7
# 154734  -6.5  1.7
# 162553  -6.5  2.7
# 363611   2.5 -3.3
# 397974   2.5 -2.3
# 425213   2.5 -1.3
# 453660   2.5 -0.3
# ⋮       ⋮    ⋮
# 1035594 30    -6
# 1083286 31   -11
# 1069564 31   -10
# 1062687 31    -9
# 1055693 31    -8
# 995107  31    -7
# 1042381 31    -6
# 1090205 32   -11
# 1076378 32   -10
# 1001811 32    -7
# 1048910 32    -6
# 325913   3   -11
# 586527   3    -7
# 630534   3    -6
# 333028   4   -11
# 579089   4    -7
# 623292   4    -6
# 340661   5   -11
# 571874   5    -7
# ...

# %%
offlineSummary$dist = sqrt(diffs[, 1]^2 + diffs[,2]^2)
xyplot(signal ~ dist | factor(mac) + factor(angle), data = offlineSummary, pch = 19, cex = 0.3, xlab = "distance")
# Out:
# plot without title

# %% [markdown]
# ## 1.5 Nearest Neighbor Methods to Predict Location

# %%
readData = 
  function(filename = 'offline.final.trace.txt', 
           subMacs = c("00:0f:a3:39:e1:c0", "00:0f:a3:39:dd:cd", "00:14:bf:b1:97:8a",
                       "00:14:bf:3b:c7:c6", "00:14:bf:b1:97:90", "00:14:bf:b1:97:8d",
                       "00:14:bf:b1:97:81"))
  {
    txt = readLines(filename)
    lines = txt[ substr(txt, 1, 1) != "#" ]
    tmp = lapply(lines, processLine)
    offline = as.data.frame(do.call("rbind", tmp), 
                            stringsAsFactors= FALSE) 
    
    names(offline) = c("time", "scanMac", 
                       "posX", "posY", "posZ", "orientation", 
                       "mac", "signal", "channel", "type")
    
     # keep only signals from access points
    offline = offline[ offline$type == "3", ]
    
    # drop scanMac, posZ, channel, and type - no info in them
    dropVars = c("scanMac", "posZ", "channel", "type")
    offline = offline[ , !( names(offline) %in% dropVars ) ]
    
    # drop more unwanted access points
    offline = offline[ offline$mac %in% subMacs, ]
    
    # convert numeric values
    numVars = c("time", "posX", "posY", "orientation", "signal")
    offline[ numVars ] = lapply(offline[ numVars ], as.numeric)

    # convert time to POSIX
    offline$rawTime = offline$time
    offline$time = offline$time/1000
    class(offline$time) = c("POSIXt", "POSIXct")
    
    # round orientations to nearest 45
    offline$angle = roundOrientation(offline$orientation)
      
    return(offline)
  }

macs = unique(offlineSummary$mac)
online = readData(filename="/home/kyle/Documents/thomaskh522@gmail.com/SMU/Quant the World/RTLS_CaseStudy/Data/online_data.txt", subMacs=macs)

# %%
online$posXY = paste(online$posX, online$posY, sep="-")
length(unique(online$posXY))
# Out:
# [1] 60

# %%
tabonlineXYA = table(online$posXY, online$angle)
tabonlineXYA[1:6,]
# Out:
#
#                0  45  90 135 180 225 270 315
#   0-0.05       0   0   0 593   0   0   0   0
#   0.15-9.42    0   0 606   0   0   0   0   0
#   0.31-11.09   0   0   0   0   0 573   0   0
#   0.47-8.2   590   0   0   0   0   0   0   0
#   0.78-10.94 586   0   0   0   0   0   0   0
#   0.93-11.69   0   0   0   0 583   0   0   0

# %%
keepVars = c("posXY", "posX", "posY", "orientation", "angle")
byLoc = with(online,
            by(online, list(posXY),
              function(x){
                  ans = x[1, keepVars]
                  avgSS = tapply(x$signal, x$mac, mean)
                  y = matrix(avgSS, nrow = 1, ncol = 6, dimnames = list(ans$posXY, names(avgSS)))
                  cbind(ans, y)
              }))

onlineSummary = do.call("rbind", byLoc)

# %%
dim(onlineSummary)
# Out:
# [1] 60 11

# %%
names(onlineSummary)
# Out:
#  [1] "posXY"             "posX"              "posY"
#  [4] "orientation"       "angle"             "00:0f:a3:39:e1:c0"
#  [7] "00:14:bf:3b:c7:c6" "00:14:bf:b1:97:81" "00:14:bf:b1:97:8a"
# [10] "00:14:bf:b1:97:8d" "00:14:bf:b1:97:90"

# %% [markdown]
# ## 1.5.2 Choice of Orientation

# %%
m = 3; angleNewObs = 230
refs = seq(0, by = 45, length  = 8)
nearestAngle = roundOrientation(angleNewObs)
  
if (m %% 2 == 1) {
  angles = seq(-45 * (m - 1) /2, 45 * (m - 1) /2, length = m)
} else {
  m = m + 1
  angles = seq(-45 * (m - 1) /2, 45 * (m - 1) /2, length = m)
  if (sign(angleNewObs - nearestAngle) > -1) 
    angles = angles[ -1 ]
  else 
    angles = angles[ -m ]
}
angles = angles + nearestAngle
angles[angles < 0] = angles[ angles < 0 ] + 360
angles[angles > 360] = angles[ angles > 360 ] - 360

offlineSubset = offlineSummary[offlineSummary$angle %in% angles,]

# %%
reshapeSS = function(data, varSignal = "signal", 
                     keepVars = c("posXY", "posX","posY")) {
  byLocation =
    with(data, by(data, list(posXY), 
                  function(x) {
                    ans = x[1, keepVars]
                    avgSS = tapply(x[ , varSignal ], x$mac, mean)
                    y = matrix(avgSS, nrow = 1, ncol = 6,
                               dimnames = list(ans$posXY,
                                               names(avgSS)))
                    cbind(ans, y)
                  }))

  newDataSS = do.call("rbind", byLocation)
  return(newDataSS)
}

# %%
trainSS = reshapeSS(offlineSubset, varSignal = 'avgSignal')

# %%
selectTrain = function(angleNewObs, signals = NULL, m = 1){
  # m is the number of angles to keep between 1 and 5
  refs = seq(0, by = 45, length  = 8)
  nearestAngle = roundOrientation(angleNewObs)
  
  if (m %% 2 == 1) 
    angles = seq(-45 * (m - 1) /2, 45 * (m - 1) /2, length = m)
  else {
    m = m + 1
    angles = seq(-45 * (m - 1) /2, 45 * (m - 1) /2, length = m)
    if (sign(angleNewObs - nearestAngle) > -1) 
      angles = angles[ -1 ]
    else 
      angles = angles[ -m ]
  }
  angles = angles + nearestAngle
  angles[angles < 0] = angles[ angles < 0 ] + 360
  angles[angles > 360] = angles[ angles > 360 ] - 360
  angles = sort(angles) 
  
  offlineSubset = signals[ signals$angle %in% angles, ]
  reshapeSS(offlineSubset, varSignal = "avgSignal")
}

# %%
train130 = selectTrain(130, offlineSummary, m=3)

# %% [markdown]
# ## 1.5.3 Finding the Nearest Neighbors

# %%
findNN = function(newSignal, trainSubset){
    diffs = apply(trainSubset[, 4:9], 1, function(x) x - newSignal)
    dists = apply(diffs, 2, function(x) sqrt(sum(x^2)))
    closest = order(dists)
    return(trainSubset[closest, 1:3])
}

# %%
estXY = lapply(closeXY, function(x) sapply(x, function(x) mean(x[1:k])))
# Out:
# Error in lapply(closeXY, function(x) sapply(x, function(x) mean(x[1:k]))): object 'closeXY' not found
# Traceback:
#
# 1. lapply(closeXY, function(x) sapply(x, function(x) mean(x[1:k])))

# %%
predXY = function(newSignals, newAngles, trainData, 
                  numAngles = 1, k = 3){
  
  closeXY = list(length = nrow(newSignals))
  
  for (i in 1:nrow(newSignals)) {
    trainSS = selectTrain(newAngles[i], trainData, m = numAngles)
    closeXY[[i]] = 
      findNN(newSignal = as.numeric(newSignals[i, ]), trainSS)
  }

  estXY = lapply(closeXY, 
                 function(x) sapply(x[ , 2:3], 
                                    function(x) mean(x[1:k])))
  estXY = do.call("rbind", estXY)
  return(estXY)
}
estXYk3 = predXY(newSignals = onlineSummary[ , 6:11], 
                 newAngles = onlineSummary[ , 4], 
                 offlineSummary, numAngles = 3, k = 3)

estXYk1 = predXY(newSignals = onlineSummary[ , 6:11], 
                 newAngles = onlineSummary[ , 4], 
                 offlineSummary, numAngles = 3, k = 1)

# %%
floorErrorMap = function(estXY, actualXY, trainPoints = NULL, AP = NULL){
  
    plot(0, 0, xlim = c(0, 35), ylim = c(-3, 15), type = "n",
         xlab = "", ylab = "", axes = FALSE)
    box()
    if ( !is.null(AP) ) points(AP, pch = 15)
    if ( !is.null(trainPoints) )
      points(trainPoints, pch = 19, col="grey", cex = 0.6)
    
    points(x = actualXY[, 1], y = actualXY[, 2], 
           pch = 19, cex = 0.8 )
    points(x = estXY[, 1], y = estXY[, 2], 
           pch = 8, cex = 0.8 )
    segments(x0 = estXY[, 1], y0 = estXY[, 2],
             x1 = actualXY[, 1], y1 = actualXY[ , 2],
             lwd = 2, col = "red")
}

# %%
trainPoints = offlineSummary[ offlineSummary$angle == 0 & 
                              offlineSummary$mac == "00:0f:a3:39:e1:c0" ,
                        c("posX", "posY")]

#pdf(file="GEO_FloorPlanK3Errors.pdf", width = 10, height = 7)
oldPar = par(mar = c(1, 1, 1, 1))
floorErrorMap(estXYk3, onlineSummary[ , c("posX","posY")], 
              trainPoints = trainPoints, AP = AP)
par(oldPar)
dev.off()
# Out:
# null device
#           1
# plot without title

# %%
#pdf(file="GEO_FloorPlanK1Errors.pdf", width = 10, height = 7)
oldPar = par(mar = c(1, 1, 1, 1))
floorErrorMap(estXYk1, onlineSummary[ , c("posX","posY")], 
              trainPoints = trainPoints, AP = AP)
par(oldPar)
dev.off()
# Out:
# null device
#           1
# plot without title

# %%
calcError = 
function(estXY, actualXY) 
   sum( rowSums( (estXY - actualXY)^2) )

actualXY = onlineSummary[ , c("posX", "posY")]
sapply(list(estXYk1, estXYk3), calcError, actualXY)
# Out:
# [1] 659.4003 306.7025

# %% [markdown]
# ## 1.5.4 Cross-Validation and Choice of K

# %%
v = 11
permuteLocs = sample(unique(offlineSummary$posXY))
permuteLocs = matrix(permuteLocs, ncol = v, 
                     nrow = floor(length(permuteLocs)/v))

onlineFold = subset(offlineSummary, posXY %in% permuteLocs[ , 1])

reshapeSS = function(data, varSignal = "signal", 
                     keepVars = c("posXY", "posX","posY"),
                     sampleAngle = FALSE, 
                     refs = seq(0, 315, by = 45)) {
  byLocation =
    with(data, by(data, list(posXY), 
                  function(x) {
                    if (sampleAngle) {
                      x = x[x$angle == sample(refs, size = 1), ]}
                    ans = x[1, keepVars]
                    avgSS = tapply(x[ , varSignal ], x$mac, mean)
                    y = matrix(avgSS, nrow = 1, ncol = 6,
                               dimnames = list(ans$posXY,
                                               names(avgSS)))
                    cbind(ans, y)
                  }))

  newDataSS = do.call("rbind", byLocation)
  return(newDataSS)
}

offline = offline[ offline$mac != "00:0f:a3:39:dd:cd", ]
# Out:
# Warning message in matrix(permuteLocs, ncol = v, nrow = floor(length(permuteLocs)/v)):
# “data length [166] is not a sub-multiple or multiple of the number of rows [15]”

# %%
keepVars = c("posXY", "posX","posY", "orientation", "angle")

onlineCVSummary = reshapeSS(offline, keepVars = keepVars, 
                            sampleAngle = TRUE)

onlineFold = subset(onlineCVSummary, 
                    posXY %in% permuteLocs[ , 1])

offlineFold = subset(offlineSummary,
                     posXY %in% permuteLocs[ , -1])

estFold = predXY(newSignals = onlineFold[ , 6:11], 
                 newAngles = onlineFold[ , 4], 
                 offlineFold, numAngles = 3, k = 3)

actualFold = onlineFold[ , c("posX", "posY")]
calcError(estFold, actualFold)

K = 20
err = rep(0, K)
# Out:
# [1] 48.44444

# %%
for (j in 1:v) {
  onlineFold = subset(onlineCVSummary, 
                      posXY %in% permuteLocs[ , j])
  offlineFold = subset(offlineSummary,
                       posXY %in% permuteLocs[ , -j])
  actualFold = onlineFold[ , c("posX", "posY")]
  
  for (k in 1:K) {
    estFold = predXY(newSignals = onlineFold[ , 6:11],
                     newAngles = onlineFold[ , 4], 
                     offlineFold, numAngles = 3, k = k)
    err[k] = err[k] + calcError(estFold, actualFold)
  }
}

# %%
#pdf(file = "Geo_CVChoiceOfK.pdf", width = 10, height = 6)
oldPar = par(mar = c(4, 3, 1, 1))
plot(y = err, x = (1:K),  type = "l", lwd= 2,
     ylim = c(1200, 2100),
     xlab = "Number of Neighbors",
     ylab = "Sum of Square Errors")

rmseMin = min(err)
kMin = which(err == rmseMin)[1]
segments(x0 = 0, x1 = kMin, y0 = rmseMin, col = gray(0.4), 
         lty = 2, lwd = 2)
segments(x0 = kMin, x1 = kMin, y0 = 1100,  y1 = rmseMin, 
         col = grey(0.4), lty = 2, lwd = 2)

#mtext(kMin, side = 1, line = 1, at = kMin, col = grey(0.4))
text(x = kMin - 2, y = rmseMin + 40, 
     label = as.character(round(rmseMin)), col = grey(0.4))
par(oldPar)
dev.off()
# Out:
# null device
#           1
# plot without title

# %%
estXYk5 = predXY(newSignals = onlineSummary[ , 6:11], 
                 newAngles = onlineSummary[ , 4], 
                 offlineSummary, numAngles = 3, k = 5)

calcError(estXYk5, actualXY)
# Out:
# [1] 275.5083

# %%
predXY = function(newSignals, newAngles, trainData, 
                  numAngles = 1, k = 3){
  
  closeXY = list(length = nrow(newSignals))
  
  for (i in 1:nrow(newSignals)) {
    trainSS = selectTrain(newAngles[i], trainData, m = numAngles)
    closeXY[[i]] = findNN(newSignal = as.numeric(newSignals[i, ]),
                           trainSS)
  }

  estXY = lapply(closeXY, function(x)
                            sapply(x[ , 2:3], 
                                    function(x) mean(x[1:k])))
  estXY = do.call("rbind", estXY)
  return(estXY)
}

# %% [markdown]
# # Questions to answer
#
# ## 1. Which of these two MAC address should be used and which should not be used for RTLS?
#
# In the paper we should frame this a question from the client. Or maybe that these two mac addresses were flagged as suspecious and further investigation was warrented.
#
# The book states that the mac ending in "cd" is a duplicate and was dropped. Having this sensor in the analysis twice might bias the results.

# %%
offline2 = readData(path2)
head(offline2)
# Out:
#   time                posX posY orientation mac               signal
# 1 2006-02-11 02:31:58 0    0    0           00:14:bf:b1:97:8a -38
# 2 2006-02-11 02:31:58 0    0    0           00:14:bf:b1:97:90 -56
# 3 2006-02-11 02:31:58 0    0    0           00:0f:a3:39:e1:c0 -53
# 4 2006-02-11 02:31:58 0    0    0           00:14:bf:b1:97:8d -65
# 5 2006-02-11 02:31:58 0    0    0           00:14:bf:b1:97:81 -65
# 6 2006-02-11 02:31:58 0    0    0           00:14:bf:3b:c7:c6 -66
#   rawTime      angle
# 1 1.139643e+12 0
# 2 1.139643e+12 0
# 3 1.139643e+12 0
# 4 1.139643e+12 0
# 5 1.139643e+12 0
# 6 1.139643e+12 0

# %%
table(offline2$mac)
# Out:
# 00:0f:a3:39:dd:cd 00:0f:a3:39:e1:c0 00:14:bf:3b:c7:c6 00:14:bf:b1:97:81
#            145619            145862            126529            120339
# 00:14:bf:b1:97:8a 00:14:bf:b1:97:8d 00:14:bf:b1:97:90
#            132962            121325            122315

# %%
macsOfInterest = c("00:0f:a3:39:dd:cd", "00:0f:a3:39:e1:c0")
investMAC = offline2[offline2$mac %in% macsOfInterest,]
dim(investMAC)
head(investMAC)
# Out:
# [1] 291481      8
#    time                posX posY orientation mac               signal
# 3  2006-02-11 02:31:58 0    0    0           00:0f:a3:39:e1:c0 -53
# 7  2006-02-11 02:31:58 0    0    0           00:0f:a3:39:dd:cd -75
# 13 2006-02-11 02:31:58 0    0    0           00:0f:a3:39:e1:c0 -54
# 19 2006-02-11 02:31:58 0    0    0           00:0f:a3:39:dd:cd -73
# 23 2006-02-11 02:31:59 0    0    0           00:0f:a3:39:e1:c0 -54
# 30 2006-02-11 02:31:59 0    0    0           00:0f:a3:39:dd:cd -65
#    rawTime      angle
# 3  1.139643e+12 0
# 7  1.139643e+12 0
# 13 1.139643e+12 0
# 19 1.139643e+12 0
# 23 1.139643e+12 0
# 30 1.139643e+12 0

# %%
library(dplyr)

# vars = c(posX, posY, orientation, signal, angle)
# stats = c(mean, median, std, min, max)

paste("posX")
investMAC %>%
select(posX, posY, signal, angle, mac) %>%
group_by(mac) %>%
summarise(mean=mean(posX), median=median(posX), min=min(posX), max=max(posX), sd=sd(posX))

paste("posY")
investMAC %>%
select(posX, posY, signal, angle, mac) %>%
group_by(mac) %>%
summarise(mean=mean(posY), median=median(posY), min=min(posY), max=max(posY), sd=sd(posY))

paste("orientation")
investMAC %>%
select(posX, posY, signal, angle, mac, orientation) %>%
group_by(mac) %>%
summarise(mean=mean(orientation), median=median(orientation), min=min(orientation), max=max(orientation), sd=sd(orientation))

paste("signal")
investMAC %>%
select(posX, posY, signal, angle, mac) %>%
group_by(mac) %>%
summarise(mean=mean(signal), median=median(signal), min=min(signal), max=max(signal), sd=sd(signal))

paste("angle")
investMAC %>%
select(posX, posY, signal, angle, mac) %>%
group_by(mac) %>%
summarise(mean=mean(angle), median=median(angle), min=min(angle), max=max(angle), sd=sd(angle))
# Out:
# [1] "posX"
#   mac               mean     median min max sd
# 1 00:0f:a3:39:dd:cd 14.15861 13     0   33  10.55295
# 2 00:0f:a3:39:e1:c0 14.24596 13     0   33  10.56928
# [1] "posY"
#   mac               mean     median min max sd
# 1 00:0f:a3:39:dd:cd 5.917058 7      0   13  2.678925
# 2 00:0f:a3:39:e1:c0 5.916387 7      0   13  2.674595
# [1] "orientation"
#   mac               mean     median min max   sd
# 1 00:0f:a3:39:dd:cd 166.8612 180    0   359.9 104.6604
# 2 00:0f:a3:39:e1:c0 166.7499 180    0   359.9 104.6196
# [1] "signal"
#   mac               mean      median min max sd
# 1 00:0f:a3:39:dd:cd -70.46225 -71    -98 -46 8.129129
# 2 00:0f:a3:39:e1:c0 -53.70182 -54    -92 -34 5.795536
# [1] "angle"
#   mac               mean     median min max sd
# 1 00:0f:a3:39:dd:cd 157.5901 180    0   315 103.1621
# 2 00:0f:a3:39:e1:c0 157.4994 180    0   315 103.1146

# %%
xyplot(signal ~ posX | factor(mac), data = investMAC, pch = 19, cex = 0.3, xlab = "posX")
xyplot(signal ~ posY | factor(mac), data = investMAC, pch = 19, cex = 0.3, xlab = "posY")
# Out:
# plot without title
# plot without title

# %%
corrData = offline[, !names(offline) %in% c("mac", "posXY", "time")]
res = cor(corrData)
res
# Out:
#             posX          posY         orientation  signal       rawtime
# posX         1.0000000000 -0.107612320  0.021100097 -0.152997144  0.5417484430
# posY        -0.1076123203  1.000000000 -0.009983813 -0.026819288  0.0877462073
# orientation  0.0211000967 -0.009983813  1.000000000 -0.002136275  0.0235655101
# signal      -0.1529971441 -0.026819288 -0.002136275  1.000000000 -0.0811554908
# rawtime      0.5417484430  0.087746207  0.023565510 -0.081155491  1.0000000000
# angle       -0.0004969705 -0.000830139  0.855045902 -0.001470629 -0.0002588261
#             angle
# posX        -0.0004969705
# posY        -0.0008301390
# orientation  0.8550459025
# signal      -0.0014706290
# rawtime     -0.0002588261
# angle        1.0000000000

# %%
install.packages("corrplot")
library("corrplot")
# Out:
# Installing package into ‘/home/kyle/R/x86_64-pc-linux-gnu-library/3.4’
# (as ‘lib’ is unspecified)
# corrplot 0.84 loaded

# %%
corrplot(res, type = "upper")
# Out:
# Plot with title “”

# %%
library(lattice)
bwplot(signal ~ factor(angle) | mac, data = offline2, subset = posX == 2 & posY == 12, layout = c(2,4))
# Out:
# plot without title

# %%
submac
# Out:
# [1] "00:0f:a3:39:e1:c0" "00:0f:a3:39:dd:cd" "00:14:bf:b1:97:8a"
# [4] "00:14:bf:3b:c7:c6" "00:14:bf:b1:97:90" "00:14:bf:b1:97:8d"
# [7] "00:14:bf:b1:97:81"

# %% [markdown]
# ## 2. Which MAC address yields the best prediction of location?
#
# First I want to do a log transformation of the signal since there appears to be a curve in the scatter plot of signal.
#
# Then I will run KNN on this new variables.

# %%
offline$absSig = abs(offline$signal)
offline$logAbsSig = log(offline$absSig)
offlineSummary$logAbsSig = log(abs(offlineSummary$signal))



head(offlineSummary)
# Out:
#        time                posX posY orientation mac               signal
# 3      2006-02-11 02:31:58 0     0   0.0         00:0f:a3:39:e1:c0 -53
# 24507  2006-02-11 03:03:44 0     1   0.7         00:0f:a3:39:e1:c0 -49
# 221774 2006-02-11 06:46:02 0    10   0.9         00:0f:a3:39:e1:c0 -53
# 229185 2006-02-11 06:54:05 0    11   0.4         00:0f:a3:39:e1:c0 -53
# 236489 2006-02-11 07:02:32 0    12   0.2         00:0f:a3:39:e1:c0 -54
# 243539 2006-02-11 07:14:12 0    13   0.1         00:0f:a3:39:e1:c0 -57
#        rawtime      angle posXY medSignal avgSignal num sdSignal iqrSignal
# 3      1.139643e+12 0     0-0   -51       -51.15455 110 1.408925 2.00
# 24507  1.139645e+12 0     0-1   -51       -50.57273 110 2.198661 3.00
# 221774 1.139658e+12 0     0-10  -56       -56.20000 110 1.123559 1.00
# 229185 1.139659e+12 0     0-11  -53       -54.68182 110 3.421282 7.00
# 236489 1.139659e+12 0     0-12  -55       -56.60000 110 3.561259 7.75
# ...

# %%
xyplot(logAbsSig ~ dist | factor(mac) + factor(angle), data=offlineSummary, pch = 20, cex = 0.2, xlab = "distance" )
# Out:
# plot without title

# %%
# Out:
# [1] 4.564348
# [1] 3.401197
